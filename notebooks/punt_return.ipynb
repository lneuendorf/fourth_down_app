# %%
import os

import pandas as pd
import numpy as np
import pymc as pm
import arviz as az
import matplotlib.pyplot as plt
import seaborn as sns
import sklearn as sk

import nfl_data_py as nfl

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.options.mode.copy_on_write = True

# %%
years = range(2000, 2024)
# columns = []
df = nfl.import_pbp_data([2023], downcast=False).query('punt_attempt==1')
df.head()
# Out:
# 2023 done.
#     play_id          game_id old_game_id home_team away_team season_type  \
# 10    245.0  2023_01_ARI_WAS  2023091007       WAS       ARI         REG
# 17    427.0  2023_01_ARI_WAS  2023091007       WAS       ARI         REG
# 60   1601.0  2023_01_ARI_WAS  2023091007       WAS       ARI         REG
# 65   1722.0  2023_01_ARI_WAS  2023091007       WAS       ARI         REG
# 75   1947.0  2023_01_ARI_WAS  2023091007       WAS       ARI         REG
#
#     week posteam posteam_type defteam side_of_field  yardline_100   game_date  \
# 10     1     WAS         home     ARI           ARI          49.0  2023-09-10
# 17     1     ARI         away     WAS           ARI          70.0  2023-09-10
# 60     1     ARI         away     WAS           ARI          85.0  2023-09-10
# 65     1     WAS         home     ARI           ARI          45.0  2023-09-10
# 75     1     ARI         away     WAS           ARI          63.0  2023-09-10
#
# ...

# %%
df.yards_gained.unique()
# Out:
# array([0.])

# %% [markdown]
# yardline_100
# ydsnet
# desc
# out_of_bounds
# special_teams_play
# play_type_nfl
# weather
# stadium
# punter_player_name
# punter_player_id
# punt_returner_player_name
# punt_returner_player_id
# lateral_punt_returner_player_id
# lateral_punt_returner_player_name
# fumble
# fumble_forced
# fumble_lost
# punt_attempt
# punt_blocked
# return_touchdown
# touchdown
# own_kickoff_recovery_td
# own_kickoff_recovery
# penalty
# punt_inside_twenty
# punt_in_endzone
# punt_out_of_bounds
# punt_downed
# punt_fair_catch
# touchback
# kick_distance
# return_team
# return_yards
# penalty_team
# penalty_yards
# penalty_type
#
#
# possible outcomes:
# - blocked punt
# - fumble and recovery by offense
# - punt return td
# - normal punt return
#
# Problem: if you predict where the opposing team gets the ball on kickof based on expectation of distibution, this only handles for one possible outcome. It does not take into account the possibilities of a blocked punt, fumble recovery by offense, punt return touchdown (kind of does this one).
#
# New model porposal:
# Regression model to predict WPA of a punt based based on field position, score differnetial, time remaining.
